# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\andre\OneDrive\Área de Trabalho\REPROGRAMA\SEMANA 12\on33-python-s12-pandas-numpy-II\material\desenvolvimento_paises.csv')

# %%
df.describe(include='all')
# Out:
#          Country  AveragScore  SafetySecurity  PersonelFreedom  Governance  \
# count        170   170.000000      170.000000       170.000000  170.000000
# unique       168          NaN             NaN              NaN         NaN
# top      Denmark          NaN             NaN              NaN         NaN
# freq           2          NaN             NaN              NaN         NaN
# mean         NaN    58.346353       67.404941        56.967118   50.814882
# std          NaN    13.405679       17.520573        20.060552   17.970393
# min          NaN    30.400000       16.540000        16.160000   13.090000
# 25%          NaN    47.840000       59.480000        39.540000   37.905000
# 50%          NaN    57.870000       69.015000        57.185000   47.660000
# 75%          NaN    67.900000       80.680000        72.967500   61.812500
# max          NaN    84.550000       96.320000        94.100000   90.410000
#
# ...
